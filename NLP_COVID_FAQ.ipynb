# %% [markdown]
# LOAD DATASET

# %%
import pandas as pd;

#Load dataset and examine dataset, rename columns to questions and answers
from google.colab import files
f=files.upload()
# Out:
#      <input type="file" id="files-5c58d005-2788-4f3b-b105-2f69b69eb324" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c58d005-2788-4f3b-b105-2f69b69eb324">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WHO_FAQ (1).xlsx to WHO_FAQ (1).xlsx

# %%
df=pd.read_excel("WHO_FAQ (1).xlsx")
df.columns=["context","answers"]

df
# Out:
#                                               context                                            answers
# 0                              What is a coronavirus?  Coronaviruses are a large family of viruses wh...
# 1                                   What is COVID-19?  COVID-19 is the infectious disease caused by t...
# 2                  What are the symptoms of COVID-19?  The most common symptoms of COVID-19 are fever...
# 3                           How does COVID-19 spread?  People can catch COVID-19 from others who have...
# 4   Can the virus that causes COVID-19 be transmit...  Studies to date suggest that the virus that ca...
# 5   Can CoVID-19 be caught from a person who has n...  The main way the disease spreads is through re...
# 6   Can I catch COVID-19 from the feces of someone...  The risk of catching COVID-19 from the feces o...
# 7   What can I do to protect myself andProtection ...  Self-isolate by staying at home if you begin t...
# 8   Protection measures for persons who are in or ...  If you develop fever, cough and difficulty bre...
# 9                  How likely am I to catch COVID-19?  The risk depends on where you  are - and more ...
# 10                 How likely am I to catch COVID-19?  COVID-19 outbreaks can be contained and transm...
# 11                      Should I worry about COVID-19  Illness due to COVID-19 infection is generally...
# 12       Who is at risk of developing severe illness?  While we are still learning about how COVID-20...
# 13  Are antibiotics effective in preventing or tre...  No. Antibiotics do not work against viruses, t...
# 14  Are there any medicines or therapies that can ...  While some western, traditional or home remedi...
# 15  Is there a vaccine, drug or treatment for COVI...  Not yet. To date, there is no vaccine and no s...
# 16                      Is COVID-19 the same as SARS?  No. The virus that causes COVID-19 and the one...
# 17             Should I wear a mask to protect myself  Only wear a mask if you are ill with COVID-19 ...
# 18  How to put on, use, take off and dispose of a ...  Remember, a mask should only be used by health...
# 19    How long is the incubation period for COVID-19?  The “incubation period” means the time between...
# 20  Can humans be infected with the COVID-19 from ...  Coronaviruses are a large family of viruses th...
# 21                  Can I catch COVID-19 from my pet?  While there has been one instance of a dog bei...
# 22       How long does the virus survive on surfaces?  It is not certain how long the virus that caus...
# 23  Is it safe to receive a package from any area ...  Yes. The likelihood of an infected person cont...
# 24                 Is there anything I should not do?                             Wearing multiple masks
# 25              Is the source causing COVID-19 known?  Currently, the source of SARS-CoV-2, the coron...
# 26  How did the first human SARS-CoV-2 infections ...  The first human cases of COVID-19 were identif...
# 27                              Is COVID-19 airborne?  The virus that causes COVID-19 is mainly trans...
# 28   Are pregnant women at higher risk from COVID-19?  At present there is no evidence that they are ...
# 29  I'm pregnant. How can I protect myself against...  Pregnant women should take the same precaution...
# 30      Should pregnant women be tested for COVID-19?  Testing protocols and eligibility vary dependi...
# 31  Can COVID-19 be passed from a woman to her unb...  We still do not know if a pregnant woman with ...
# 32  What care should be available during pregnancy...  All pregnant women, including those with confi...
# 33  Do pregnant women with suspected or confirmed ...  No. WHO advice is that caesarean sections shou...
# 34                Can women with COVID-19 breastfeed?  Yes. Women with COVID-19 can breastfeed if the...
# 35  Can I touch and hold my newborn baby if I have...  Yes. Close contact and early, exclusive breast...
# 36    How are COVID-19 and influenza viruses similar?  COVID-19 and influenza viruses have a similar ...
# 37  How are COVID-19 and influenza viruses different?  The speed of transmission is an important poin...
# 38  What medical interventions are available for C...  While there are a number of therapeutics curre...
# 39  Are smokers and tobacco users at higher risk o...  Smoking products such as water pipes often inv...
# 40  How large does a meeting or event need to be i...  High profile international sporting events suc...
# 41  Does WHO recommend that all international mass...  No. As each international mass gathering is di...

# %% [markdown]
# TEXT PREPROCESSING

# %%
import re
import gensim 
from gensim.parsing.preprocessing import remove_stopwords


def clean_sentence(sentence, stopwords=False):
    
    sentence = sentence.lower().strip()
    sentence = re.sub(r'[^a-z0-9\s]', '', sentence)
    
    if stopwords:
         sentence = remove_stopwords(sentence)
    
    
    return sentence
                    
def get_cleaned_sentences(df,stopwords=False):    
    sents=df[["context"]]
    cleaned_sentences=[]

    for index,row in df.iterrows():
        #print(index,row)
        cleaned=clean_sentence(row["context"],stopwords);
        cleaned_sentences.append(cleaned);
    return cleaned_sentences;

cleaned_sentences=get_cleaned_sentences(df,stopwords=True)
print(cleaned_sentences);

print("\n")

cleaned_sentences_with_stopwords=get_cleaned_sentences(df,stopwords=False)
print(cleaned_sentences_with_stopwords);
# Out:
# ['coronavirus', 'covid19', 'symptoms covid19', 'covid19 spread', 'virus causes covid19 transmitted air', 'covid19 caught person symptoms', 'catch covid19 feces disease', 'protect andprotection measures persons recently visited past 14 days areas covid19 spreading prevent spread disease', 'protection measures persons recently visited past 14 days areas covid19 spreading', 'likely catch covid19', 'likely catch covid19', 'worry covid19', 'risk developing severe illness', 'antibiotics effective preventing treating covid19', 'medicines therapies prevent cure covid19', 'vaccine drug treatment covid19', 'covid19 sars', 'wear mask protect', 'use dispose mask', 'long incubation period covid19', 'humans infected covid19 animal source', 'catch covid19 pet', 'long virus survive surfaces', 'safe receive package area covid19 reported', '', 'source causing covid19 known', 'human sarscov2 infections occur', 'covid19 airborne', 'pregnant women higher risk covid19', 'im pregnant protect covid19', 'pregnant women tested covid19', 'covid19 passed woman unborn baby', 'care available pregnancy childbirth', 'pregnant women suspected confirmed covid19 need birth ceasarean section', 'women covid19 breastfeed', 'touch hold newborn baby covid19', 'covid19 influenza viruses similar', 'covid19 influenza viruses different', 'medical interventions available covid19 influenza viruses', 'smokers tobacco users higher risk covid19 infection', 'large meeting event need order mass gathering', 'recommend international mass gatherings cancelled covid19']
#
#
# ['what is a coronavirus', 'what is covid19', 'what are the symptoms of covid19', 'how does covid19 spread', 'can the virus that causes covid19 be transmitted through the air', 'can covid19 be caught from a person who has no symptoms', 'can i catch covid19 from the feces of someone with the disease', 'what can i do to protect myself andprotection measures for persons who are in or have recently visited past 14 days areas where covid19 is spreading prevent the spread of disease', 'protection measures for persons who are in or have recently visited past 14 days areas where covid19 is spreading', 'how likely am i to catch covid19', 'how likely am i to catch covid19', 'should i worry about covid19', 'who is at risk of developing severe illness', 'are antibiotics effective in preventing or treating the covid19', 'are there any medicines or therapies that can prevent or cure covid19', 'is there a vaccine drug or treatment for covid19', 'is covid19 the same as sars', 'should i wear a mask to protect myself', 'how to put on use take off and dispose of a mask', 'how long is the incubation period for covid19', 'can humans be infected with the covid19 from an animal source', 'can i catch covid19 from my pet', 'how long does the virus survive on surfaces', 'is it safe to receive a package from any area where covid19 has been reported', 'is there anything i should not do', 'is the source causing covid19 known', 'how did the first human sarscov2 infections occur', 'is covid19 airborne', 'are pregnant women at higher risk from covid19', 'im pregnant how can i protect myself against covid19', 'should pregnant women be tested for covid19', 'can covid19 be passed from a woman to her unborn baby', 'what care should be available during pregnancy and childbirth', 'do pregnant women with suspected or confirmed covid19 need to give birth by ceasarean section', 'can women with covid19 breastfeed', 'can i touch and hold my newborn baby if i have covid19', 'how are covid19 and influenza viruses similar', 'how are covid19 and influenza viruses different', 'what medical interventions are available for covid19 and influenza viruses', 'are smokers and tobacco users at higher risk of covid19 infection', 'how large does a meeting or event need to be in order to be a mass gathering', 'does who recommend that all international mass gatherings be cancelled because of covid19']

# %% [markdown]
# VECTOR REPRESENTATION: BAG OF WORDS (BOW) MODEL

# %%
import numpy

sentences=cleaned_sentences_with_stopwords


# Split it by white space 
sentence_words = [[word for word in document.split() ]
         for document in sentences]

from gensim import corpora

dictionary = corpora.Dictionary(sentence_words)
for key, value in dictionary.items():
    print(key, ' : ', value)

import pprint
bow_corpus = [dictionary.doc2bow(text) for text in sentence_words]
for sent,embedding in zip(sentences,bow_corpus):
    print(sent)
    print(embedding)

question_orig=" can i get covid through air ?"
question=clean_sentence(question_orig,stopwords=False);
question_embedding = dictionary.doc2bow(question.split())


print("\n\n",question,"\n",question_embedding)
# Out:
# 0  :  a
# 1  :  coronavirus
# 2  :  is
# 3  :  what
# 4  :  covid19
# 5  :  are
# 6  :  of
# 7  :  symptoms
# 8  :  the
# 9  :  does
# 10  :  how
# 11  :  spread
# 12  :  air
# 13  :  be
# 14  :  can
# 15  :  causes
# 16  :  that
# 17  :  through
# 18  :  transmitted
# 19  :  virus
# 20  :  caught
# 21  :  from
# 22  :  has
# 23  :  no
# 24  :  person
# 25  :  who
# 26  :  catch
# 27  :  disease
# 28  :  feces
# 29  :  i
# 30  :  someone
# 31  :  with
# 32  :  14
# 33  :  andprotection
# 34  :  areas
# 35  :  days
# 36  :  do
# 37  :  for
# 38  :  have
# 39  :  in
# 40  :  measures
# 41  :  myself
# 42  :  or
# 43  :  past
# 44  :  persons
# 45  :  prevent
# 46  :  protect
# 47  :  recently
# 48  :  spreading
# 49  :  to
# 50  :  visited
# 51  :  where
# 52  :  protection
# 53  :  am
# 54  :  likely
# 55  :  about
# 56  :  should
# 57  :  worry
# 58  :  at
# 59  :  developing
# 60  :  illness
# 61  :  risk
# 62  :  severe
# 63  :  antibiotics
# 64  :  effective
# 65  :  preventing
# 66  :  treating
# 67  :  any
# 68  :  cure
# 69  :  medicines
# 70  :  therapies
# 71  :  there
# 72  :  drug
# 73  :  treatment
# 74  :  vaccine
# 75  :  as
# 76  :  same
# 77  :  sars
# 78  :  mask
# 79  :  wear
# 80  :  and
# 81  :  dispose
# 82  :  off
# 83  :  on
# 84  :  put
# 85  :  take
# 86  :  use
# 87  :  incubation
# 88  :  long
# 89  :  period
# 90  :  an
# 91  :  animal
# 92  :  humans
# 93  :  infected
# 94  :  source
# 95  :  my
# 96  :  pet
# 97  :  surfaces
# 98  :  survive
# 99  :  area
# 100  :  been
# 101  :  it
# 102  :  package
# 103  :  receive
# 104  :  reported
# 105  :  safe
# 106  :  anything
# 107  :  not
# 108  :  causing
# 109  :  known
# 110  :  did
# 111  :  first
# 112  :  human
# 113  :  infections
# 114  :  occur
# 115  :  sarscov2
# 116  :  airborne
# 117  :  higher
# 118  :  pregnant
# 119  :  women
# 120  :  against
# 121  :  im
# 122  :  tested
# 123  :  baby
# 124  :  her
# 125  :  passed
# 126  :  unborn
# 127  :  woman
# 128  :  available
# 129  :  care
# 130  :  childbirth
# 131  :  during
# 132  :  pregnancy
# 133  :  birth
# 134  :  by
# 135  :  ceasarean
# 136  :  confirmed
# 137  :  give
# 138  :  need
# 139  :  section
# 140  :  suspected
# 141  :  breastfeed
# 142  :  hold
# 143  :  if
# 144  :  newborn
# 145  :  touch
# 146  :  influenza
# 147  :  similar
# 148  :  viruses
# 149  :  different
# 150  :  interventions
# 151  :  medical
# 152  :  infection
# 153  :  smokers
# 154  :  tobacco
# 155  :  users
# 156  :  event
# 157  :  gathering
# 158  :  large
# 159  :  mass
# 160  :  meeting
# 161  :  order
# 162  :  all
# 163  :  because
# 164  :  cancelled
# 165  :  gatherings
# 166  :  international
# 167  :  recommend
# what is a coronavirus
# [(0, 1), (1, 1), (2, 1), (3, 1)]
# what is covid19
# [(2, 1), (3, 1), (4, 1)]
# what are the symptoms of covid19
# [(3, 1), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1)]
# how does covid19 spread
# [(4, 1), (9, 1), (10, 1), (11, 1)]
# can the virus that causes covid19 be transmitted through the air
# [(4, 1), (8, 2), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1)]
# can covid19 be caught from a person who has no symptoms
# [(0, 1), (4, 1), (7, 1), (13, 1), (14, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1)]
# can i catch covid19 from the feces of someone with the disease
# [(4, 1), (6, 1), (8, 2), (14, 1), (21, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1)]
# what can i do to protect myself andprotection measures for persons who are in or have recently visited past 14 days areas where covid19 is spreading prevent the spread of disease
# [(2, 1), (3, 1), (4, 1), (5, 1), (6, 1), (8, 1), (11, 1), (14, 1), (25, 1), (27, 1), (29, 1), (32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1), (51, 1)]
# protection measures for persons who are in or have recently visited past 14 days areas where covid19 is spreading
# [(2, 1), (4, 1), (5, 1), (25, 1), (32, 1), (34, 1), (35, 1), (37, 1), (38, 1), (39, 1), (40, 1), (42, 1), (43, 1), (44, 1), (47, 1), (48, 1), (50, 1), (51, 1), (52, 1)]
# how likely am i to catch covid19
# [(4, 1), (10, 1), (26, 1), (29, 1), (49, 1), (53, 1), (54, 1)]
# how likely am i to catch covid19
# [(4, 1), (10, 1), (26, 1), (29, 1), (49, 1), (53, 1), (54, 1)]
# should i worry about covid19
# [(4, 1), (29, 1), (55, 1), (56, 1), (57, 1)]
# who is at risk of developing severe illness
# [(2, 1), (6, 1), (25, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1)]
# are antibiotics effective in preventing or treating the covid19
# [(4, 1), (5, 1), (8, 1), (39, 1), (42, 1), (63, 1), (64, 1), (65, 1), (66, 1)]
# are there any medicines or therapies that can prevent or cure covid19
# [(4, 1), (5, 1), (14, 1), (16, 1), (42, 2), (45, 1), (67, 1), (68, 1), (69, 1), (70, 1), (71, 1)]
# is there a vaccine drug or treatment for covid19
# [(0, 1), (2, 1), (4, 1), (37, 1), (42, 1), (71, 1), (72, 1), (73, 1), (74, 1)]
# is covid19 the same as sars
# [(2, 1), (4, 1), (8, 1), (75, 1), (76, 1), (77, 1)]
# should i wear a mask to protect myself
# [(0, 1), (29, 1), (41, 1), (46, 1), (49, 1), (56, 1), (78, 1), (79, 1)]
# how to put on use take off and dispose of a mask
# [(0, 1), (6, 1), (10, 1), (49, 1), (78, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 1)]
# how long is the incubation period for covid19
# [(2, 1), (4, 1), (8, 1), (10, 1), (37, 1), (87, 1), (88, 1), (89, 1)]
# can humans be infected with the covid19 from an animal source
# [(4, 1), (8, 1), (13, 1), (14, 1), (21, 1), (31, 1), (90, 1), (91, 1), (92, 1), (93, 1), (94, 1)]
# can i catch covid19 from my pet
# [(4, 1), (14, 1), (21, 1), (26, 1), (29, 1), (95, 1), (96, 1)]
# how long does the virus survive on surfaces
# [(8, 1), (9, 1), (10, 1), (19, 1), (83, 1), (88, 1), (97, 1), (98, 1)]
# is it safe to receive a package from any area where covid19 has been reported
# [(0, 1), (2, 1), (4, 1), (21, 1), (22, 1), (49, 1), (51, 1), (67, 1), (99, 1), (100, 1), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1)]
# is there anything i should not do
# [(2, 1), (29, 1), (36, 1), (56, 1), (71, 1), (106, 1), (107, 1)]
# is the source causing covid19 known
# [(2, 1), (4, 1), (8, 1), (94, 1), (108, 1), (109, 1)]
# how did the first human sarscov2 infections occur
# [(8, 1), (10, 1), (110, 1), (111, 1), (112, 1), (113, 1), (114, 1), (115, 1)]
# is covid19 airborne
# [(2, 1), (4, 1), (116, 1)]
# are pregnant women at higher risk from covid19
# [(4, 1), (5, 1), (21, 1), (58, 1), (61, 1), (117, 1), (118, 1), (119, 1)]
# im pregnant how can i protect myself against covid19
# [(4, 1), (10, 1), (14, 1), (29, 1), (41, 1), (46, 1), (118, 1), (120, 1), (121, 1)]
# should pregnant women be tested for covid19
# [(4, 1), (13, 1), (37, 1), (56, 1), (118, 1), (119, 1), (122, 1)]
# can covid19 be passed from a woman to her unborn baby
# [(0, 1), (4, 1), (13, 1), (14, 1), (21, 1), (49, 1), (123, 1), (124, 1), (125, 1), (126, 1), (127, 1)]
# what care should be available during pregnancy and childbirth
# [(3, 1), (13, 1), (56, 1), (80, 1), (128, 1), (129, 1), (130, 1), (131, 1), (132, 1)]
# do pregnant women with suspected or confirmed covid19 need to give birth by ceasarean section
# [(4, 1), (31, 1), (36, 1), (42, 1), (49, 1), (118, 1), (119, 1), (133, 1), (134, 1), (135, 1), (136, 1), (137, 1), (138, 1), (139, 1), (140, 1)]
# can women with covid19 breastfeed
# [(4, 1), (14, 1), (31, 1), (119, 1), (141, 1)]
# can i touch and hold my newborn baby if i have covid19
# [(4, 1), (14, 1), (29, 2), (38, 1), (80, 1), (95, 1), (123, 1), (142, 1), (143, 1), (144, 1), (145, 1)]
# how are covid19 and influenza viruses similar
# [(4, 1), (5, 1), (10, 1), (80, 1), (146, 1), (147, 1), (148, 1)]
# how are covid19 and influenza viruses different
# [(4, 1), (5, 1), (10, 1), (80, 1), (146, 1), (148, 1), (149, 1)]
# what medical interventions are available for covid19 and influenza viruses
# [(3, 1), (4, 1), (5, 1), (37, 1), (80, 1), (128, 1), (146, 1), (148, 1), (150, 1), (151, 1)]
# are smokers and tobacco users at higher risk of covid19 infection
# [(4, 1), (5, 1), (6, 1), (58, 1), (61, 1), (80, 1), (117, 1), (152, 1), (153, 1), (154, 1), (155, 1)]
# how large does a meeting or event need to be in order to be a mass gathering
# [(0, 2), (9, 1), (10, 1), (13, 2), (39, 1), (42, 1), (49, 2), (138, 1), (156, 1), (157, 1), (158, 1), (159, 1), (160, 1), (161, 1)]
# does who recommend that all international mass gatherings be cancelled because of covid19
# [(4, 1), (6, 1), (9, 1), (13, 1), (16, 1), (25, 1), (159, 1), (162, 1), (163, 1), (164, 1), (165, 1), (166, 1), (167, 1)]
#
#
#  can i get covid through air
#  [(12, 1), (14, 1), (17, 1), (29, 1)]

# %%
import sklearn
from sklearn.metrics.pairwise import cosine_similarity;

def retrieveAndPrintFAQAnswer(question_embedding,sentence_embeddings,FAQdf,sentences):
    max_sim=-1;
    index_sim=-1;
    for index,faq_embedding in enumerate(sentence_embeddings):
        sim=cosine_similarity(faq_embedding,question_embedding)[0][0]
        print(index, sim, sentences[index])
        if sim>max_sim:
            max_sim=sim;
            index_sim=index;
       
    print("\n")
    print("Question: ",question)
    print("\n");
    print("Retrieved: ",FAQdf.iloc[index_sim,0]) 
    print(FAQdf.iloc[index_sim,1])        
    
print( retrieveAndPrintFAQAnswer(question_embedding,bow_corpus,df,sentences) )
# Out:
# 0 0.08304547985373997 what is a coronavirus
# 1 0.9284766908852593 what is covid19
# 2 0.9716676031619468 what are the symptoms of covid19
# 3 0.986932880775682 how does covid19 spread
# 4 0.986932880775682 can the virus that causes covid19 be transmitted through the air
# 5 0.08304547985373997 can covid19 be caught from a person who has no symptoms
# 6 0.986932880775682 can i catch covid19 from the feces of someone with the disease
# 7 0.9284766908852593 what can i do to protect myself andprotection measures for persons who are in or have recently visited past 14 days areas where covid19 is spreading prevent the spread of disease
# 8 0.9284766908852593 protection measures for persons who are in or have recently visited past 14 days areas where covid19 is spreading
# 9 0.986932880775682 how likely am i to catch covid19
# 10 0.986932880775682 how likely am i to catch covid19
# 11 0.986932880775682 should i worry about covid19
# 12 0.9284766908852593 who is at risk of developing severe illness
# 13 0.986932880775682 are antibiotics effective in preventing or treating the covid19
# 14 0.986932880775682 are there any medicines or therapies that can prevent or cure covid19
# 15 0.08304547985373997 is there a vaccine drug or treatment for covid19
# 16 0.9284766908852593 is covid19 the same as sars
# 17 0.08304547985373997 should i wear a mask to protect myself
# 18 0.08304547985373997 how to put on use take off and dispose of a mask
# 19 0.9284766908852593 how long is the incubation period for covid19
# 20 0.986932880775682 can humans be infected with the covid19 from an animal source
# 21 0.986932880775682 can i catch covid19 from my pet
# 22 0.9991508330917331 how long does the virus survive on surfaces
# 23 0.08304547985373997 is it safe to receive a package from any area where covid19 has been reported
# 24 0.9284766908852593 is there anything i should not do
# 25 0.9284766908852593 is the source causing covid19 known
# 26 0.9991508330917331 how did the first human sarscov2 infections occur
# 27 0.9284766908852593 is covid19 airborne
# 28 0.986932880775682 are pregnant women at higher risk from covid19
# 29 0.986932880775682 im pregnant how can i protect myself against covid19
# 30 0.986932880775682 should pregnant women be tested for covid19
# 31 0.08304547985373997 can covid19 be passed from a woman to her unborn baby
# 32 0.9716676031619468 what care should be available during pregnancy and childbirth
# 33 0.986932880775682 do pregnant women with suspected or confirmed covid19 need to give birth by ceasarean section
# 34 0.986932880775682 can women with covid19 breastfeed
# 35 0.986932880775682 can i touch and hold my newborn baby if i have covid19
# 36 0.986932880775682 how are covid19 and influenza viruses similar
# 37 0.986932880775682 how are covid19 and influenza viruses different
# 38 0.9716676031619468 what medical interventions are available for covid19 and influenza viruses
# 39 0.986932880775682 are smokers and tobacco users at higher risk of covid19 infection
# 40 0.08304547985373997 how large does a meeting or event need to be in order to be a mass gathering
# 41 0.986932880775682 does who recommend that all international mass gatherings be cancelled because of covid19
#
#
# Question:  can i get covid through air
#
#
# Retrieved:  How long does the virus survive on surfaces?
# It is not certain how long the virus that causes COVID-19 survives on surfaces, but it seems to behave like other coronaviruses.
# None

# %% [markdown]
# WORD2VEC EMBEDDING

# %%
from gensim.models import Word2Vec 
import gensim.downloader as api

v2w_model=None;
try:
    v2w_model = gensim.models.KeyedVectors.load("./w2vecmodel.mod")
    print("Loaded w2v model")
except:            
    v2w_model = api.load('word2vec-google-news-300')
    v2w_model.save("./w2vecmodel.mod")
    print("Saved word2v model")

w2vec_embedding_size=len(v2w_model['computer']);
w2vec_embedding_size
# Out:
# Loaded w2v model
# 300

# %%
def getWordVec(word,model):
        samp=model['computer']
        vec=[0]*len(samp)
        try:
                vec=model[word]
        except:
                vec=[0]*len(samp)
        return (vec)


def getPhraseEmbedding(phrase,embeddingmodel):
                       
        samp=getWordVec('computer', embeddingmodel)
        vec=numpy.array([0]*len(samp))
        den=0;
        for word in phrase.split():
            #print(word)
            den=den+1;
            vec=vec+numpy.array(getWordVec(word,embeddingmodel))
        return vec.reshape(1, -1)

# %%
sent_embeddings=[];
for sent in cleaned_sentences:
    sent_embeddings.append(getPhraseEmbedding(sent,v2w_model))

question_embedding=getPhraseEmbedding(question,v2w_model)

retrieveAndPrintFAQAnswer(question_embedding,sent_embeddings,df, cleaned_sentences)
# Out:
# 0 0.014743232701589958 coronavirus
# 1 0.0 covid19
# 2 0.09510770487268361 symptoms covid19
# 3 0.21974295663091586 covid19 spread
# 4 0.4271661419471191 virus causes covid19 transmitted air
# 5 0.22947491576239845 covid19 caught person symptoms
# 6 0.26729394856137184 catch covid19 feces disease
# 7 0.31261409076180513 protect andprotection measures persons recently visited past 14 days areas covid19 spreading prevent spread disease
# 8 0.2642899717547245 protection measures persons recently visited past 14 days areas covid19 spreading
# 9 0.349217036724078 likely catch covid19
# 10 0.349217036724078 likely catch covid19
# 11 0.2348425295788565 worry covid19
# 12 0.16020520341425687 risk developing severe illness
# 13 0.17159759083457218 antibiotics effective preventing treating covid19
# 14 0.17381523529751147 medicines therapies prevent cure covid19
# 15 0.10840807935893484 vaccine drug treatment covid19
# 16 0.14178550930542885 covid19 sars
# 17 0.2765302987392187 wear mask protect
# 18 0.29182739390706486 use dispose mask
# 19 0.22888712605343337 long incubation period covid19
# 20 0.24155384283546744 humans infected covid19 animal source
# 21 0.30407276828476154 catch covid19 pet
# 22 0.35921189518209584 long virus survive surfaces
# 23 0.31532539912833374 safe receive package area covid19 reported
# 24 0.0
# 25 0.23476690137562886 source causing covid19 known
# 26 0.23574265221625698 human sarscov2 infections occur
# 27 0.2737752847601561 covid19 airborne
# 28 0.18106614008186 pregnant women higher risk covid19
# 29 0.39655280978583335 im pregnant protect covid19
# 30 0.16656436648445436 pregnant women tested covid19
# 31 0.15829573583451498 covid19 passed woman unborn baby
# 32 0.24219544116196798 care available pregnancy childbirth
# 33 0.22310471752172564 pregnant women suspected confirmed covid19 need birth ceasarean section
# 34 0.1375875423433095 women covid19 breastfeed
# 35 0.2531605929229601 touch hold newborn baby covid19
# 36 0.17037088809636658 covid19 influenza viruses similar
# 37 0.20538519172644776 covid19 influenza viruses different
# 38 0.22324825212004784 medical interventions available covid19 influenza viruses
# 39 0.23930654609956512 smokers tobacco users higher risk covid19 infection
# 40 0.2634416275914599 large meeting event need order mass gathering
# 41 0.19256120753460523 recommend international mass gatherings cancelled covid19
#
#
# Question:  can i get covid through air
#
#
# Retrieved:  Can the virus that causes COVID-19 be transmitted through the air?
# Studies to date suggest that the virus that causes COVID-19 is mainly transmitted through contact with respiratory droplets rather than through the air.
